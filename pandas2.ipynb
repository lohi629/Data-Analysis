# %%
import pandas as pd
d={'num':[1,2,3,4,5,6],'even':[2,4,6,8,10,12],'odd':[1,3,5,7,9,11]}
df=pd.DataFrame(d)
print(df)
# Out:
#    num  even  odd
# 0    1     2    1
# 1    2     4    3
# 2    3     6    5
# 3    4     8    7
# 4    5    10    9
# 5    6    12   11

# %%
print(pd.__version__)
# Out:
# 1.3.4

# %%
#series
d=[1,3,7]
ser=pd.Series(d)
print(ser)
print(ser[0])
d2={'day1':300,'day2':400,'day3':500}
ser2=pd.Series(d2,index=['day1','day2'])
print(ser2)
# Out:
# 0    1
# 1    3
# 2    7
# dtype: int64
# 1
# day1    300
# day2    400
# dtype: int64

# %%
#locating row in dataframe
print(df.loc[1])
print(df.loc[[1,2]])
# Out:
# num     2
# even    4
# odd     3
# Name: 1, dtype: int64
#    num  even  odd
# 1    2     4    3
# 2    3     6    5

# %%
df3=pd.read_csv('C:\\Users\\y20cs95\\Desktop\\data.csv')
print(pd.options.display.max_rows)
pd.options.display.max_rows=9999
print(df3)
# Out:
# 9999
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
#analyzing the dataframes
print(df3.head(3))
print(df3.tail(3))
print(df3.info())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
#      Duration  Pulse  Maxpulse  Calories
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
# None

# %%
print(df3.loc[df3['Calories'].isnull()])
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 17         45     90       112       NaN
# 27         60    103       132       NaN
# 91         45    107       137       NaN
# 118        60    105       125       NaN
# 141        60     97       127       NaN

# %%
df3['Calories'].fillna(0,inplace=True)
print(df3['Calories'])
# Out:
# 0       409.1
# 1       479.0
# 2       340.0
# 3       282.4
# 4       406.0
# 5       300.0
# 6       374.0
# 7       253.3
# 8       195.1
# 9       269.0
# 10      329.3
# 11      250.7
# 12      345.3
# 13      379.3
# 14      275.0
# 15      215.2
# 16      300.0
# 17        0.0
# 18      323.0
# 19      243.0
# 20      364.2
# 21      282.0
# 22      300.0
# 23      246.0
# 24      334.5
# 25      250.0
# 26      241.0
# 27        0.0
# 28      280.0
# 29      380.3
# 30      243.0
# 31      180.1
# 32      299.0
# 33      223.0
# 34      361.0
# 35      415.0
# 36      300.0
# 37      300.0
# 38      300.0
# 39      266.0
# 40      180.1
# 41      286.0
# 42      329.4
# 43      400.0
# 44      397.0
# 45      273.0
# 46      387.6
# 47      300.0
# 48      298.0
# 49      397.6
# 50      380.2
# 51      643.1
# 52      263.0
# 53      486.0
# 54      238.0
# 55      450.7
# 56      413.0
# 57      305.0
# 58      226.4
# 59      321.0
# 60     1376.0
# 61     1034.4
# ...

# %%
df3.replace(to_replace = 'NaN', value ='False')
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       0.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...
