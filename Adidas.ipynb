# %% [markdown]
# <a href="https://colab.research.google.com/github/lohi629/Data-Analysis/blob/main/Adidas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_excel("/content/Adidas_Dataset.xlsx")
df
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker      1185732   2020-01-01  Northeast       New York
# 1     Foot Locker      1185732   2020-01-02  Northeast       New York
# 2     Foot Locker      1185732   2020-01-03  Northeast       New York
# 3     Foot Locker      1185732   2020-01-04  Northeast       New York
# 4     Foot Locker      1185732   2020-01-05  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9644  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9646  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
#
#             City                    Product  Price per Unit  Units Sold  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   int64
#  2   Invoice Date      9648 non-null   datetime64[ns]
#  3   Region            9648 non-null   object
#  4   State             9648 non-null   object
#  5   City              9648 non-null   object
#  6   Product           9648 non-null   object
#  7   Price per Unit    9648 non-null   float64
#  8   Units Sold        9648 non-null   int64
#  9   Total Sales       9648 non-null   float64
#  10  Operating Profit  9648 non-null   float64
#  11  Operating Margin  9648 non-null   float64
#  12  Sales Method      9648 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(6)
# memory usage: 980.0+ KB

# %%
df[(df['Retailer ID'].isnull()==False)]['Retailer'].unique()
# Out:
# array(['Foot Locker', 'Walmart', 'Sports Direct', 'West Gear', "Kohl's",
#        'Amazon'], dtype=object)

# %%
temp=df.groupby('Region')
li=set(df['Region'])
for i in li:
  print(i,"******")
  print(list(temp.get_group(i)['Retailer']))
# Out:
# Southeast ******
# ...

# %%
temp=df.groupby(['City','State'])
temp['Retailer'].unique().apply(list)
# Out:
# City            State
# Albany          New York                              [West Gear, Kohl's]
# Albuquerque     New Mexico                        [Kohl's, Sports Direct]
# Anchorage       Alaska                              [Amazon, Foot Locker]
# Atlanta         Georgia                      [Sports Direct, Foot Locker]
# Baltimore       Maryland          [West Gear, Foot Locker, Sports Direct]
# Billings        Montana                           [Kohl's, Sports Direct]
# Birmingham      Alabama                           [Sports Direct, Amazon]
# Boise           Idaho             [Foot Locker, West Gear, Sports Direct]
# Boston          Massachusetts                     [Sports Direct, Amazon]
# Burlington      Vermont                               [Amazon, West Gear]
# Charleston      South Carolina               [Foot Locker, Sports Direct]
#                 West Virginia                    [West Gear, Foot Locker]
# ...

# %%
df.groupby(['Retailer','City'])['Product'].unique().apply(list)
# Out:
# Retailer   City
# Amazon     Anchorage         [Women's Apparel, Men's Street Footwear, Men's...
#            Birmingham        [Men's Street Footwear, Men's Athletic Footwea...
#            Boston            [Women's Apparel, Men's Street Footwear, Men's...
#            Burlington        [Women's Athletic Footwear, Men's Apparel, Wom...
#            Charlotte         [Women's Street Footwear, Women's Athletic Foo...
#                                                    ...
# West Gear  Portland          [Men's Street Footwear, Men's Athletic Footwea...
#            Salt Lake City    [Women's Athletic Footwear, Men's Apparel, Wom...
#            San Francisco     [Men's Apparel, Women's Apparel, Men's Street ...
#            Seattle           [Men's Apparel, Women's Apparel, Men's Street ...
#            St. Louis         [Women's Street Footwear, Women's Athletic Foo...
# Name: Product, Length: 108, dtype: object

# %%
df.groupby('Retailer')['Total Sales'].sum()
# Out:
# Retailer
# Amazon            77698912.0
# Foot Locker      220094720.0
# Kohl's           102114753.0
# Sports Direct    182470997.0
# Walmart           74558410.0
# West Gear        242964333.0
# Name: Total Sales, dtype: float64

# %%
df.groupby(['Retailer','City'])[['Total Sales','Operating Profit']].sum()
# Out:
#                           Total Sales  Operating Profit
# Retailer  City
# Amazon    Anchorage        13365025.0        4143804.75
#           Birmingham         409091.0         146947.48
#           Boston            4193590.0        1375377.31
#           Burlington       13380463.0        5376161.02
#           Charlotte         3733676.0        1532481.72
# ...                               ...               ...
# West Gear Portland         21934257.0        7712540.80
#           Salt Lake City    9696420.0        3873429.10
#           San Francisco    33360397.0        9843005.12
#           Seattle          24862675.0        6469771.84
#           St. Louis         1701133.0         681457.25
#
# [108 rows x 2 columns]

# %%
df.groupby(['Retailer','Product'])[['Total Sales','Operating Profit']].sum()
# Out:
#                                          Total Sales  Operating Profit
# Retailer      Product
# Amazon        Men's Apparel               10474770.0        3331443.80
#               Men's Athletic Footwear     12011959.0        4518030.11
#               Men's Street Footwear       22161652.0        8707658.12
#               Women's Apparel             15710639.0        6280071.53
#               Women's Athletic Footwear    7935255.0        2701607.74
#               Women's Street Footwear      9404637.0        3279692.01
# Foot Locker   Men's Apparel               29508995.0        9942404.61
#               Men's Athletic Footwear     36480415.0       12409221.49
#               Men's Street Footwear       57481575.0       23060809.17
#               Women's Apparel             43296114.0       17192901.49
#               Women's Athletic Footwear   24239624.0        8477313.73
#               Women's Street Footwear     29087997.0        9639474.32
# ...

# %%
df[df['Invoice Date'].between('2020-01-01','2020-04-15')][['Units Sold','Total Sales','Operating Profit']]
# Out:
#       Units Sold  Total Sales  Operating Profit
# 0           1200     600000.0         300000.00
# 1           1000     500000.0         150000.00
# 2           1000     400000.0         140000.00
# 3            850     382500.0         133875.00
# 4            900     540000.0         162000.00
# ...          ...          ...               ...
# 8275         170       9520.0           1713.60
# 8276         149       2980.0           1192.00
# 8277         145       4495.0           1123.75
# 8278         128       3328.0           1397.76
# 8279          96       2496.0            848.64
#
# [425 rows x 3 columns]

# %%
df.groupby(['City','Retailer','Product'])['Units Sold'].sum()
# Out:
# City        Retailer  Product
# Albany      Kohl's    Men's Apparel                1375
#                       Men's Athletic Footwear      1401
#                       Men's Street Footwear        2104
#                       Women's Apparel              1613
#                       Women's Athletic Footwear    1311
#                                                    ...
# Wilmington  Kohl's    Men's Athletic Footwear      1490
#                       Men's Street Footwear        2638
#                       Women's Apparel              1743
#                       Women's Athletic Footwear     970
#                       Women's Street Footwear      1525
# Name: Units Sold, Length: 618, dtype: int64

# %%
df.groupby(['Product','City'])['Price per Unit'].unique()
# Out:
# Product                  City
# Men's Apparel            Albany         [55.00000000000001, 60.0, 65.0, 60.00000000000...
#                          Albuquerque    [50.000000000000014, 60.00000000000001, 70.0, ...
#                          Anchorage      [65.00000000000001, 60.00000000000001, 65.0, 7...
#                          Atlanta        [45.000000000000014, 55.00000000000001, 65.0, ...
#                          Baltimore      [45.0, 49.99999999999999, 60.0, 50.0, 41.0, 43...
#                                                               ...
# Women's Street Footwear  Seattle        [50.0, 64.99999999999999, 75.0, 65.0, 80.0, 85...
#                          Sioux Falls    [30.000000000000004, 45.0, 35.0, 40.0, 50.0, 2...
#                          St. Louis      [25.000000000000007, 20.000000000000007, 30.00...
#                          Wichita        [10.000000000000002, 15.000000000000002, 35.0,...
# ...

# %%
import datetime as dt
from datetime import date
#df['Invoice Date']=df['Invoice Date'].dt.month
df.groupby(['Product','Invoice Date'])[['Total Sales','Operating Profit']].sum()
# Out:
#                                       Total Sales  Operating Profit
# Product                 Invoice Date
# Men's Apparel           1              10253418.0        4140975.27
#                         2               9231558.0        3733361.25
#                         3               7574392.0        2964310.83
#                         4               9904477.0        3924164.27
#                         5              11466847.0        4557076.66
# ...                                           ...               ...
# Women's Street Footwear 8              13556630.0        4610492.85
#                         9              11512326.0        4172597.58
#                         10              8906290.0        3187944.57
#                         11              8824858.0        3053346.22
#                         12             11499517.0        4047079.39
#
# [72 rows x 2 columns]

# %%
df.groupby(['City','Product','Sales Method'])[['Total Sales','Operating Profit']].sum()
# Out:
#                                                    Total Sales  \
# City       Product                   Sales Method
# Albany     Men's Apparel             In-store        3776250.0
#                                      Online            97303.0
#            Men's Athletic Footwear   In-store        3732500.0
#                                      Online            97096.0
#            Men's Street Footwear     In-store        5626250.0
# ...                                                        ...
# Wilmington Women's Apparel           Online            64155.0
#            Women's Athletic Footwear In-store        1211250.0
#                                      Online            31330.0
#            Women's Street Footwear   In-store        1464750.0
#                                      Online            37547.0
#
#                                                    Operating Profit
# City       Product                   Sales Method
# ...
