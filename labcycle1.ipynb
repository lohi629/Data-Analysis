# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\y20cs95\\Desktop\\project_data.csv")
df
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 0       20201701            1982        Graduation         Single
# 1       20201702            1950        Graduation        Married
# 2       20201703            1965        Graduation       Divorced
# 3       20201704            1984        Graduation   Relationship
# 4       20201705            1981               PhD        Widowed
# ..           ...             ...               ...            ...
# 494     20202195            1944               PhD       Divorced
# 495     20202196            1962            Master       Divorced
# 496     20202197            1978        Graduation       Divorced
# 497     20202198            1971               PhD   Relationship
# 498     20202199            1949               PhD   Relationship
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0          58138.0    09-04-2012       58                 8                4
# ...

# %%
#first 5 rows
df.head()
# Out:
#    customer_id  year_of_birth  educational_level marital_status  \
# 0     20201701            1982        Graduation         Single
# 1     20201702            1950        Graduation        Married
# 2     20201703            1965        Graduation       Divorced
# 3     20201704            1984        Graduation   Relationship
# 4     20201705            1981               PhD        Widowed
#
#    annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0        58138.0    09-04-2012       58                 8                4
# 1        46344.0    03-08-2014       38                 1                2
# 2        71613.0     8/21/2013       26                 8               10
# 3        26646.0    02-10-2014       26                 2                4
# 4        58293.0     1/19/2014       94                 5                6
#
#    complaints  calls  intercoms
# 0           0      3         11
# 1           0      3         11
# ...

# %%
#last 5 rows
df.tail()
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 494     20202195            1944               PhD       Divorced
# 495     20202196            1962            Master       Divorced
# 496     20202197            1978        Graduation       Divorced
# 497     20202198            1971               PhD   Relationship
# 498     20202199            1949               PhD   Relationship
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 494        55614.0    11/27/2013       85                 9                6
# 495        59432.0     4/13/2013       88                 5               11
# 496        55563.0    04-05-2014       22                 2                3
# 497        43624.0     4/21/2013       83                 4                4
# 498        41461.0     5/22/2014       63                 6               11
#
#      complaints  calls  intercoms
# 494           0      3         11
# 495           0      3         11
# ...

# %%
#basic info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        499 non-null    int64
#  1   year_of_birth      499 non-null    int64
#  2   educational_level  499 non-null    object
#  3   marital_status     499 non-null    object
#  4   annual_income      486 non-null    float64
#  5   purhcase_date      499 non-null    object
#  6   recency            499 non-null    int64
#  7   online_purchases   499 non-null    int64
#  8   store_purchases    499 non-null    int64
#  9   complaints         499 non-null    int64
#  10  calls              499 non-null    int64
#  11  intercoms          499 non-null    int64
# dtypes: float64(1), int64(8), object(3)
# memory usage: 46.9+ KB

# %%
#shape
df.shape
# Out:
# (499, 12)

# %%
#unique
df['marital_status'].unique()
# Out:
# array(['Single', 'Married', 'Divorced', 'Relationship', 'Widowed',
#        'Widow'], dtype=object)

# %%
df.isna() #check for null values
# Out:
#      customer_id  year_of_birth   educational_level  marital_status  \
# 0          False           False              False           False
# 1          False           False              False           False
# 2          False           False              False           False
# 3          False           False              False           False
# 4          False           False              False           False
# ..           ...             ...                ...             ...
# 494        False           False              False           False
# 495        False           False              False           False
# 496        False           False              False           False
# 497        False           False              False           False
# 498        False           False              False           False
#
#      annual_income  purhcase_date  recency  online_purchases  store_purchases  \
# ...

# %%
df.duplicated() #check for duplicates
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 494    False
# 495    False
# 496    False
# 497    False
# 498    False
# Length: 499, dtype: bool

# %%
#consistency
df['marital_status'].replace('Widow','Widowed',inplace=True)

# %%
df['marital_status'].unique()
# Out:
# array(['Single', 'Married', 'Divorced', 'Relationship', 'Widowed'],
#       dtype=object)

# %% [markdown]
# # 3

# %%
df[['year_of_birth ','educational_level','annual_income']]
# Out:
#      year_of_birth  educational_level  annual_income
# 0              1982        Graduation        58138.0
# 1              1950        Graduation        46344.0
# 2              1965        Graduation        71613.0
# 3              1984        Graduation        26646.0
# 4              1981               PhD        58293.0
# ..              ...               ...            ...
# 494            1944               PhD        55614.0
# 495            1962            Master        59432.0
# 496            1978        Graduation        55563.0
# 497            1971               PhD        43624.0
# 498            1949               PhD        41461.0
#
# [499 rows x 3 columns]

# %%
df.loc[0:6]
# Out:
#    customer_id  year_of_birth  educational_level marital_status  \
# 0     20201701            1982        Graduation         Single
# 1     20201702            1950        Graduation        Married
# 2     20201703            1965        Graduation       Divorced
# 3     20201704            1984        Graduation   Relationship
# 4     20201705            1981               PhD        Widowed
# 5     20201706            1967            Master   Relationship
# 6     20201707            1971        Graduation       Divorced
#
#    annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0        58138.0    09-04-2012       58                 8                4
# 1        46344.0    03-08-2014       38                 1                2
# 2        71613.0     8/21/2013       26                 8               10
# 3        26646.0    02-10-2014       26                 2                4
# 4        58293.0     1/19/2014       94                 5                6
# ...

# %%
df.iloc[0:7]
# Out:
#    customer_id  year_of_birth  educational_level marital_status  \
# 0     20201701            1982        Graduation         Single
# 1     20201702            1950        Graduation        Married
# 2     20201703            1965        Graduation       Divorced
# 3     20201704            1984        Graduation   Relationship
# 4     20201705            1981               PhD        Widowed
# 5     20201706            1967            Master   Relationship
# 6     20201707            1971        Graduation       Divorced
#
#    annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0        58138.0    09-04-2012       58                 8                4
# 1        46344.0    03-08-2014       38                 1                2
# 2        71613.0     8/21/2013       26                 8               10
# 3        26646.0    02-10-2014       26                 2                4
# 4        58293.0     1/19/2014       94                 5                6
# ...

# %%
#filtering of data using loc
p=df.loc[df.educational_level=='PhD']
p
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 4       20201705            1981               PhD        Widowed
# 7       20201708            1985               PhD        Married
# 8       20201709            1974               PhD        Widowed
# 9       20201710            1950               PhD         Single
# 15      20201716            1960               PhD   Relationship
# ..           ...             ...               ...            ...
# 485     20202186            1964               PhD       Divorced
# 490     20202191            1958               PhD   Relationship
# 494     20202195            1944               PhD       Divorced
# 497     20202198            1971               PhD   Relationship
# 498     20202199            1949               PhD   Relationship
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 4          58293.0     1/19/2014       94                 5                6
# ...

# %%
#filtering data using isin()
new=p['educational_level'].isin(['PhD'])
print(new)
p[new]
# Out:
# 4      True
# 7      True
# 8      True
# 9      True
# 15     True
#        ...
# 485    True
# 490    True
# 494    True
# 497    True
# 498    True
# Name: educational_level, Length: 114, dtype: bool
#      customer_id  year_of_birth  educational_level marital_status  \
# 4       20201705            1981               PhD        Widowed
# 7       20201708            1985               PhD        Married
# 8       20201709            1974               PhD        Widowed
# 9       20201710            1950               PhD         Single
# 15      20201716            1960               PhD   Relationship
# ..           ...             ...               ...            ...
# 485     20202186            1964               PhD       Divorced
# 490     20202191            1958               PhD   Relationship
# 494     20202195            1944               PhD       Divorced
# 497     20202198            1971               PhD   Relationship
# ...

# %%
df.loc[(df.annual_income>75000) & (df.educational_level=='PhD')]
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 15      20201716            1960               PhD   Relationship
# 29      20201730            1965               PhD   Relationship
# 164     20201865            1952               PhD   Relationship
# 175     20201876            1990               PhD   Relationship
# 176     20201877            1991               PhD        Widowed
# 177     20201878            1992               PhD   Relationship
# 203     20201904            1989               PhD         Single
# 222     20201923            1990               PhD       Divorced
# 228     20201929            1996               PhD        Widowed
# 237     20201938            1982               PhD   Relationship
# 339     20202040            1899               PhD         Single
# 389     20202090            1980               PhD        Widowed
# 407     20202108            1989               PhD   Relationship
# ...

# %% [markdown]
# # 4

# %%
df.set_index('customer_id')
# Out:
#              year_of_birth  educational_level marital_status  annual_income  \
# customer_id
# 20201701               1982        Graduation         Single        58138.0
# 20201702               1950        Graduation        Married        46344.0
# 20201703               1965        Graduation       Divorced        71613.0
# 20201704               1984        Graduation   Relationship        26646.0
# 20201705               1981               PhD        Widowed        58293.0
# ...                     ...               ...            ...            ...
# 20202195               1944               PhD       Divorced        55614.0
# 20202196               1962            Master       Divorced        59432.0
# 20202197               1978        Graduation       Divorced        55563.0
# 20202198               1971               PhD   Relationship        43624.0
# 20202199               1949               PhD   Relationship        41461.0
#
# ...

# %%
df.sort_values('year_of_birth ')
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 339     20202040            1899               PhD         Single
# 32      20201733            1940        Graduation        Married
# 358     20202059            1943            Master        Married
# 39      20201740            1943               PhD       Divorced
# 494     20202195            1944               PhD       Divorced
# ..           ...             ...               ...            ...
# 16      20201717            2000        Graduation        Married
# 418     20202119            2000        Graduation         Single
# 116     20201817            2000        Graduation   Relationship
# 185     20201886            2000        Graduation         Single
# 452     20202153            2000            Master         Single
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 339        83532.0     9/26/2013       36                 4                4
# ...

# %%
df['sum']=df['online_purchases']+df['store_purchases']
df
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 0       20201701            1982        Graduation         Single
# 1       20201702            1950        Graduation        Married
# 2       20201703            1965        Graduation       Divorced
# 3       20201704            1984        Graduation   Relationship
# 4       20201705            1981               PhD        Widowed
# ..           ...             ...               ...            ...
# 494     20202195            1944               PhD       Divorced
# 495     20202196            1962            Master       Divorced
# 496     20202197            1978        Graduation       Divorced
# 497     20202198            1971               PhD   Relationship
# 498     20202199            1949               PhD   Relationship
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0          58138.0    09-04-2012       58                 8                4
# ...

# %%
 df['customer_id']=df['customer_id'].astype('datetime64[ns]')
df['customer_id']
# Out:
# 0     1970-01-01 00:00:00.020201701
# 1     1970-01-01 00:00:00.020201702
# 2     1970-01-01 00:00:00.020201703
# 3     1970-01-01 00:00:00.020201704
# 4     1970-01-01 00:00:00.020201705
#                    ...
# 494   1970-01-01 00:00:00.020202195
# 495   1970-01-01 00:00:00.020202196
# 496   1970-01-01 00:00:00.020202197
# 497   1970-01-01 00:00:00.020202198
# 498   1970-01-01 00:00:00.020202199
# Name: customer_id, Length: 499, dtype: datetime64[ns]

# %%
from datetime import datetime, date
today=date.today()
print(today)
age=today.year-(df['year_of_birth '])
print(age)
# Out:
# 2022-11-15
# 0      40
# 1      72
# 2      57
# 3      38
# 4      41
#        ..
# 494    78
# 495    60
# 496    44
# 497    51
# 498    73
# Name: year_of_birth , Length: 499, dtype: int64

# %% [markdown]
# # 5

# %%
a=pd.DataFrame(df.groupby('educational_level')[['annual_income','recency','online_purchases','store_purchases']].mean()).reset_index()
a
# Out:
#   educational_level  annual_income    recency  online_purchases  \
# 0             Basic   19514.571429  53.571429          1.571429
# 1        Graduation   51607.827309  47.171206          3.887160
# 2       High School   44154.717949  58.400000          3.450000
# 3            Master   51191.700000  45.000000          4.049383
# 4               PhD   55878.990991  49.008772          4.429825
#
#    store_purchases
# 0         2.857143
# 1         5.840467
# 2         4.600000
# 3         5.691358
# 4         6.298246

# %%
import numpy as np
a=pd.DataFrame(pd.pivot_table(df,values=['sum','recency'],index=['educational_level'],columns=['marital_status'],aggfunc={'recency':np.mean,'sum':np.sum},fill_value=0)).reset_index()
a
# Out:
#                educational_level    recency                          \
# marital_status                     Divorced    Married Relationship
# 0                          Basic  68.333333   0.000000    39.333333
# 1                     Graduation  54.897959  42.701493    48.196078
# 2                    High School  64.666667  66.866667    49.615385
# 3                         Master  60.083333  50.315789    36.800000
# 4                            PhD  41.350000  60.000000    43.161290
#
#                                           sum                              \
# marital_status     Single    Widowed Divorced Married Relationship Single
# 0               52.000000   0.000000       13       0           15      3
# 1               44.278689  48.724138      481     652          464    623
# 2               49.000000  66.666667       31     120           99     54
# 3               42.761905  37.111111      134     193          159    218
# ...
