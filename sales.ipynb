# %% [markdown]
# <a href="https://colab.research.google.com/github/lohi629/Data-Analysis/blob/main/sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/content/supermarket_sales.csv')
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
#Output the first few rows of data
df.head(7)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
# ...

# %%
#Output data dimensions (i.e. the number of rows and columns of the dataset)
df.shape
# Out:
# (1000, 17)

# %%
#Output the column header names
list(df.columns)
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Unit price',
#  'Quantity',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'Payment',
#  'cogs',
#  'gross margin percentage',
#  'gross income',
#  'Rating']

# %%
#Obtain detailed information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
#Output statistical information about the dataset
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
#Output the third row of the data frame
df.loc[3]
# Out:
# Invoice ID                       123-19-1176
# Branch                                     A
# City                                  Yangon
# Customer type                         Member
# Gender                                  Male
# Product line               Health and beauty
# Unit price                             58.22
# Quantity                                   8
# Tax 5%                                23.288
# Total                                489.048
# Date                               1/27/2019
# Time                                   20:33
# Payment                              Ewallet
# cogs                                  465.76
# gross margin percentage             4.761905
# gross income                          23.288
# Rating                                   8.4
# rank                                       1
# Rank                                    None
# Name: 3, dtype: object

# %%
#Output the last row of the data frame
df.loc[len(df)-1]
# Out:
# Invoice ID                         849-09-3807
# Branch                                       A
# City                                    Yangon
# Customer type                           Member
# Gender                                  Female
# Product line               Fashion accessories
# Unit price                               88.34
# Quantity                                     7
# Tax 5%                                  30.919
# Total                                  649.299
# Date                                 2/18/2019
# Time                                     13:28
# Payment                                   Cash
# cogs                                    618.38
# gross margin percentage               4.761905
# gross income                            30.919
# Rating                                     6.6
# rank                                         1
# Rank                                      None
# Name: 999, dtype: object

# %%
#Output the last 3 columns of the data frame
df.iloc[:,-3:]
# Out:
#      Rating  rank  Rank
# 0       9.1     1  None
# 1       9.6     1  None
# 2       7.4     1  None
# 3       8.4     1  None
# 4       5.3     1  None
# ..      ...   ...   ...
# 995     6.2     1  None
# 996     4.4     1  None
# 997     7.7     1  None
# 998     4.1     1  None
# 999     6.6     1  None
#
# [1000 rows x 3 columns]

# %%
#Output information about the object and bool data types data within the dataset
p=df.select_dtypes(include=['bool','object'])
mylist = list(p.columns)
mylist
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Date',
#  'Time',
#  'Payment',
#  'Rank']

# %%
#total data type is float, can we get information about the number ofinterger32?
p=df.select_dtypes(include=['int'])
mylist = list(p.columns)
mylist
# Out:
# ['Quantity', 'rank']

# %%
df.drop(['rank','Rank'],axis=1,inplace=True)

# %%
df['Rating_Rank'] = df['Rating'].rank(ascending = 0)
df = df.set_index('Rating_Rank')
df = df.sort_index()
  
df
# Out:
#               Invoice ID Branch       City Customer type  Gender  \
# Rating_Rank
# 3.0          347-34-2234      B   Mandalay        Member  Female
# 3.0          285-68-5083      C  Naypyitaw        Member  Female
# 3.0          423-57-2993      B   Mandalay        Normal    Male
# 3.0          725-56-0833      A     Yangon        Normal  Female
# 3.0          866-70-2814      B   Mandalay        Normal  Female
# ...                  ...    ...        ...           ...     ...
# 995.0        510-95-6347      B   Mandalay        Member  Female
# 995.0        730-61-8757      B   Mandalay        Member    Male
# 995.0        182-69-8360      B   Mandalay        Normal  Female
# 995.0        885-56-0389      C  Naypyitaw        Member    Male
# 995.0        131-15-8856      C  Naypyitaw        Member  Female
#
#                        Product line  Unit price  Quantity   Tax 5%     Total  \
# Rating_Rank
# 3.0               Sports and travel       55.07         9  24.7815  520.4115
# ...

# %%
df[df['gross income'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [Invoice ID, Branch, City, Customer type, Gender, Product line, Unit price, Quantity, Tax 5%, Total, Date, Time, Payment, cogs, gross margin percentage, gross income, Rating]
# Index: []

# %%
df[df['Total'].isnull()==False]
# Out:
#               Invoice ID Branch       City Customer type  Gender  \
# Rating_Rank
# 3.0          347-34-2234      B   Mandalay        Member  Female
# 3.0          285-68-5083      C  Naypyitaw        Member  Female
# 3.0          423-57-2993      B   Mandalay        Normal    Male
# 3.0          725-56-0833      A     Yangon        Normal  Female
# 3.0          866-70-2814      B   Mandalay        Normal  Female
# ...                  ...    ...        ...           ...     ...
# 995.0        510-95-6347      B   Mandalay        Member  Female
# 995.0        730-61-8757      B   Mandalay        Member    Male
# 995.0        182-69-8360      B   Mandalay        Normal  Female
# 995.0        885-56-0389      C  Naypyitaw        Member    Male
# 995.0        131-15-8856      C  Naypyitaw        Member  Female
#
#                        Product line  Unit price  Quantity   Tax 5%     Total  \
# Rating_Rank
# 3.0               Sports and travel       55.07         9  24.7815  520.4115
# ...

# %%
df['']
